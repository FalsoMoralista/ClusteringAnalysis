# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import os
#os.environ['KMP_DUPLICATE_LIB_OK']='True'
import pandas as pd
#import tensorflow_addons as tfa
#print(tfa.__version__)
import pickle
#import random
#from sklearn.metrics import f1_score
#from sklearn.metrics import accuracy_score
#from sklearn.metrics import classification_report as cr
#import seaborn as sns

# %%
length
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/w4/0dl8g1ps7db034jbgcvzs7_r0000gn/T/ipykernel_4795/3440210189.py in <module>
# ----> 1 length
#
# NameError: name 'length' is not defined

# %%
inetHopkinsD2 =  pd.DataFrame()
for i in range(1,9):
  path = '../resources/ImageNet/d=2/output{}.csv'
  dataFrame = pd.read_csv(path.format(i))
  inetHopkinsD2 = inetHopkinsD2.append(dataFrame, ignore_index=True)

averages = inetHopkinsD2.loc[:, 'avg']
std = inetHopkinsD2.loc[:, 'std']
ids = inetHopkinsD2.loc[:, 'id']

m = averages[np.argmax(averages)]
print(m)
mmin = averages[np.argmin(averages)]
print(mmin)
  
inetHopkinsD2
# Out:
# 1.0
# 0.321677390187174
#              id       avg       std
# 0      10003327  0.618339  0.029546
# 1      10008016  0.617029  0.032100
# 2      10009770  0.409577  0.052388
# 3      10010617  0.784081  0.015019
# 4      10012036  0.775507  0.012917
# ...         ...       ...       ...
# 68648   9970254  0.760185  0.013503
# 68649   9970373  0.704450  0.015249
# 68650   9973032  0.759064  0.020391
# 68651   9990896  0.580846  0.089819
# 68652   9998215  0.761240  0.019803
#
# [68653 rows x 3 columns]

# %%
filteredHopkinsD2 = inetHopkinsD2[inetHopkinsD2['avg'] >= 0.7] 
filteredHopkinsD2
# Out:
#              id       avg       std
# 3      10010617  0.784081  0.015019
# 4      10012036  0.775507  0.012917
# 6      10027741  0.753944  0.014084
# 9      10040445  0.744064  0.011519
# 13     10060678  0.786582  0.015212
# ...         ...       ...       ...
# 68647   9968008  0.759743  0.013128
# 68648   9970254  0.760185  0.013503
# 68649   9970373  0.704450  0.015249
# 68650   9973032  0.759064  0.020391
# 68652   9998215  0.761240  0.019803
#
# [31403 rows x 3 columns]

# %%
m-mmin
# Out:
# 0.678322609812826

# %%
lenght
# Out:
# 0.045221507320855066

# %%
N_points = len(averages)
n_bins = 15
lenght = (m - mmin)/n_bins
fig, axs = plt.subplots(figsize=(14,6))

#plt.figure(figsize=(10,6))
#0.592653975517827
# We can set the number of bins with the *bins* keyword argument.
plt.xticks(np.arange(0.3, 1, 0.05))
axs.hist(averages, bins=n_bins)
plt.xlim(right=1)
plt.title('Frequência de Classes x AVG Hopkins Statistics (100 runs) with D=2 ImageNET Embeddings')
#xlim(left=1)

#axs[1].hist(dist2, bins=n_bins)
# Out:
# Text(0.5, 1.0, 'Frequência de Classes x AVG Hopkins Statistics (100 runs) with D=2 ImageNET Embeddings')

# %%
inetHopkinsD1 = pd.read_csv('../resources/ImageNet/hopkins_statistics_INET_features_d=1.csv')

averages = inetHopkinsD1.loc[:, 'avg']
std = inetHopkinsD1.loc[:, 'std']
ids = inetHopkinsD1.loc[:, 'id']

m = averages[np.argmax(averages)]
print(m)
mmin = averages[np.argmin(averages)]
print(mmin)

inetHopkinsD1
# Out:
# 1.0
# 0.407346024482173
#              id       avg       std
# 0      10003327  0.557608  0.013237
# 1      10008016  0.564253  0.017061
# 2      10009770  0.458361  0.026654
# 3      10010617  0.665219  0.009505
# 4      10012036  0.658380  0.007868
# ...         ...       ...       ...
# 68648   9970254  0.647665  0.006910
# 68649   9970373  0.607744  0.007638
# 68650   9973032  0.656478  0.016610
# 68651   9990896  0.530740  0.046558
# 68652   9998215  0.648650  0.009063
#
# [68653 rows x 3 columns]

# %%
N_points = len(averages)
n_bins = 15
lenght = (m - mmin)/n_bins
fig, axs = plt.subplots(figsize=(14,6))

plt.xticks(np.arange(0.4, 0.9, 0.05))
plt.hist(averages, bins=n_bins)
#plt.xlim(right=0.9)
plt.title('Frequência de Classes x AVG Hopkins Statistics (100 runs)')

#xlim(left=1)

#axs[1].hist(dist2, bins=n_bins)
# Out:
# Text(0.5, 1.0, 'Frequência de Classes x AVG Hopkins Statistics (100 runs)')

# %%
filteredHopkinsD1 = inetHopkinsD1[inetHopkinsD1['avg'] >= 0.7] 
filteredHopkinsD1
# Out:
#              id       avg       std
# 119    10685706  0.807648  0.047797
# 189    10727294  0.838766  0.196425
# 205    10733097  0.769022  0.137105
# 295    10793075  0.742308  0.202960
# 350    10835811  0.866238  0.146523
# ...         ...       ...       ...
# 67428   8879961  0.712287  0.012975
# 68017   9422351  0.728782  0.055795
# 68464   9650504  0.711091  0.059672
# 68619   9819723  0.702109  0.020715
# 68634   9914638  0.758294  0.026131
#
# [352 rows x 3 columns]

# %%
ids[0:9999]
# Out:
# 0       10003327
# 1       10008016
# 2       10009770
# 3       10010617
# 4       10012036
#           ...
# 9994     2845855
# 9995     2845876
# 9996     2845882
# 9997     2845894
# 9998     2845901
# Name: id, Length: 9999, dtype: int64

# %%
# to-do: review: 
# Frequency vs density histograms!!

# %%
with open('../resources/class_dictionary.pkl', 'rb') as f:
    data = pickle.load(f)
data
# Out:
# {2683260: 0,
#  2683214: 1,
#  2683283: 2,
#  2683262: 3,
#  2683209: 4,
#  2683264: 5,
#  2683259: 6,
#  2683265: 7,
#  2683238: 8,
#  2683293: 9,
#  2683245: 10,
#  2683234: 11,
#  2683252: 12,
#  2683207: 13,
#  2683250: 14,
#  2683254: 15,
#  2683217: 16,
#  2683272: 17,
#  2683297: 18,
#  2683286: 19,
#  2683228: 20,
#  2683266: 21,
#  5284011: 22,
#  5284014: 23,
#  2683648: 24,
#  4000158: 25,
#  2683634: 26,
#  4000135: 27,
#  2683629: 28,
#  2683637: 29,
#  2683645: 30,
#  2683652: 31,
#  2683631: 32,
#  2683628: 33,
#  2683650: 34,
#  2683642: 35,
#  2683625: 36,
#  6067581: 37,
#  4000216: 38,
#  2683644: 39,
#  2683499: 40,
#  2683503: 41,
#  2683501: 42,
#  2683516: 43,
#  2683500: 44,
#  2683517: 45,
#  2683495: 46,
#  7729924: 47,
#  2683520: 48,
#  2683722: 49,
#  2683825: 50,
#  2683711: 51,
#  2683784: 52,
#  2683679: 53,
#  2683703: 54,
#  2683828: 55,
#  2683743: 56,
#  2683778: 57,
#  2683713: 58,
#  2683807: 59,
#  2683783: 60,
#  2683748: 61,
#  2683742: 62,
#  2683786: 63,
#  2683759: 64,
#  9848396: 65,
#  2683756: 66,
#  2683827: 67,
#  2683749: 68,
#  2683750: 69,
#  2865952: 878,
#  2865970: 879,
#  2865980: 880,
#  2865948: 881,
#  2865979: 882,
#  5329260: 883,
#  5329253: 884,
#  2865448: 885,
#  5329202: 886,
#  5329212: 887,
#  2866113: 888,
#  5329597: 889,
#  9179530: 890,
#  5329611: 891,
#  5329618: 892,
#  5329622: 893,
#  5329609: 894,
#  5329631: 895,
#  5329570: 896,
#  5329272: 897,
#  5329266: 898,
#  2865557: 899,
#  2865556: 900,
#  2865565: 901,
#  2865550: 902,
#  5329643: 903,
#  5329640: 904,
#  5329315: 905,
#  5329454: 906,
#  5329293: 907,
#  5329460: 908,
#  5329388: 909,
#  5329324: 910,
#  5329434: 911,
#  5329466: 912,
#  5329424: 913,
#  2865574: 914,
#  5329551: 915,
#  5329515: 916,
#  5329547: 917,
#  5329500: 918,
#  5329511: 919,
#  5329501: 920,
#  5329480: 921,
#  5329192: 922,
#  5329593: 923,
#  5329591: 924,
#  2865501: 925,
#  2865503: 926,
#  2865524: 927,
#  2865496: 928,
#  2865504: 929,
#  2865526: 930,
#  7963909: 931,
#  7970188: 932,
#  8418358: 933,
#  8168507: 934,
#  2865314: 935,
#  7451400: 936,
#  2865400: 937,
#  2865357: 938,
#  6310011: 939,
#  2865355: 940,
#  2865390: 941,
#  2865364: 942,
#  2865316: 943,
#  2865306: 944,
#  2865315: 945,
#  2865367: 946,
#  2865368: 947,
#  2865365: 948,
#  2865280: 949,
#  8010297: 950,
#  2865321: 951,
#  2865297: 952,
#  5328658: 953,
#  5328663: 954,
#  6386027: 955,
#  4009380: 956,
#  2653038: 957,
#  2653041: 958,
#  5642345: 959,
#  5301175: 960,
#  5301159: 961,
#  5642008: 962,
#  6389089: 963,
#  5301229: 964,
#  5642221: 965,
#  7289632: 966,
#  7689610: 967,
#  5301196: 968,
#  5301162: 969,
#  5641935: 970,
#  7289668: 971,
#  5301163: 972,
#  5642289: 973,
#  5301148: 974,
#  5642110: 975,
#  7629840: 976,
#  5301191: 977,
#  5301204: 978,
#  5301183: 979,
#  5301154: 980,
#  5301138: 981,
#  5301141: 982,
#  5642407: 983,
#  5642303: 984,
#  5301147: 985,
#  5301179: 986,
#  5301233: 987,
#  5301146: 988,
#  5301231: 989,
#  7289647: 990,
#  7289642: 991,
#  5301200: 992,
#  5301226: 993,
#  5301213: 994,
#  5301137: 995,
#  8351789: 996,
#  5301198: 997,
#  5301182: 998,
#  8295923: 999,
#  ...}

# %%
train_images = pd.read_csv('../resources/train_images.csv')
validation_images = pd.read_csv('../resources/validation_images.csv')

# %%
train_image_list = train_images['image_paths']
validation_image_list = validation_images['image_paths']

# %%
images_by_class = {}
for c in train_image_list:
  split = c.split('/')
  c_id = split[0]
  img = split[1]
  try:
    images_by_class[c_id]
  except Exception:
    images_by_class[c_id] = []
  finally:
    images_by_class[c_id].append(img)
    
for c in validation_image_list:
  split = c.split('/')
  c_id = split[0]
  img = split[1]
  try:
    images_by_class[c_id]
  except Exception:
    images_by_class[c_id] = []
  finally:
    images_by_class[c_id].append(img)

# %%
# Sanity Check
dataset_classlist = list(data.keys())
l = 0
for i in dataset_classlist:
  l += len(images_by_class[str(i)])
l
# Out:
# 2885052

# %%
filteredHopkinsD2
# Out:
#              id       avg       std
# 3      10010617  0.784081  0.015019
# 4      10012036  0.775507  0.012917
# 6      10027741  0.753944  0.014084
# 9      10040445  0.744064  0.011519
# 13     10060678  0.786582  0.015212
# ...         ...       ...       ...
# 68647   9968008  0.759743  0.013128
# 68648   9970254  0.760185  0.013503
# 68649   9970373  0.704450  0.015249
# 68650   9973032  0.759064  0.020391
# 68652   9998215  0.761240  0.019803
#
# [31403 rows x 3 columns]

# %%
indexes = filteredHopkinsD2['id']
img_quantities = []
for index in indexes:
  img_quantities.append(len(images_by_class[str(index)]))
hop = filteredHopkinsD2['avg']

# %%
filteredHopkinsD2_dataframe['img_quantities']
# Out:
# 0        101
# 1         99
# 2         73
# 3         73
# 4         94
#         ...
# 31398     90
# 31399    101
# 31400     50
# 31401     56
# 31402     73
# Name: img_quantities, Length: 31403, dtype: int64

# %%
filteredHopkinsD2_dataframe = pd.DataFrame({'class_ids': indexes, 'img_quantities': img_quantities, 'hopkins': hop})
filteredHopkinsD2_dataframe = filteredHopkinsD2_dataframe.reset_index(drop=True)
filteredHopkinsD2_dataframe
# Out:
#             ids  img_quantities   hopkins
# 0      10010617             101  0.784081
# 1      10012036              99  0.775507
# 2      10027741              73  0.753944
# 3      10040445              73  0.744064
# 4      10060678              94  0.786582
# ...         ...             ...       ...
# 31398   9968008              90  0.759743
# 31399   9970254             101  0.760185
# 31400   9970373              50  0.704450
# 31401   9973032              56  0.759064
# 31402   9998215              73  0.761240
#
# [31403 rows x 3 columns]

# %%
filteredHopkinsD2_dataframe = filteredHopkinsD2_dataframe[filteredHopkinsD2_dataframe['img_quantities'] >= 10] 
filteredHopkinsD2_dataframe
# Out:
#             ids  img_quantities   hopkins
# 0      10010617             101  0.784081
# 1      10012036              99  0.775507
# 2      10027741              73  0.753944
# 3      10040445              73  0.744064
# 4      10060678              94  0.786582
# ...         ...             ...       ...
# 31398   9968008              90  0.759743
# 31399   9970254             101  0.760185
# 31400   9970373              50  0.704450
# 31401   9973032              56  0.759064
# 31402   9998215              73  0.761240
#
# [31201 rows x 3 columns]

# %%
filteredHopkinsD2_dataframe.to_csv('inet_clusterable_classes.csv')

# %%
N_points
# Out:
# 31403

# %%
lenght
# Out:
# 12.333333333333334

# %%
mmax = filteredHopkinsD2_dataframe['img_quantities'][np.argmax(filteredHopkinsD2_dataframe['img_quantities'])]
print(mmax)
mmin = filteredHopkinsD2_dataframe['img_quantities'][np.argmin(filteredHopkinsD2_dataframe['img_quantities'])]
print(mmin)

N_points = len(filteredHopkinsD2_dataframe['ids'])
n_bins = 5
lenght = (mmax - mmin)/n_bins
fig, axs = plt.subplots(figsize=(14,6))

#plt.figure(figsize=(10,6))
#0.592653975517827
# We can set the number of bins with the *bins* keyword argument.
#plt.xticks(np.arange(3, 160, int(lenght)))
axs.hist(filteredHopkinsD2_dataframe['img_quantities'], bins=n_bins)
plt.xlim(right=160)
plt.title('Frequência de Classes Particionáveis (Hopkins D=2) Vs Qtd. Imagens')

#xlim(left=1)

#axs[1].hist(dist2, bins=n_bins)
# Out:
# 151
# 3
# Text(0.5, 1.0, 'Frequência de Classes Particionáveis (Hopkins D=2) Vs Qtd. Imagens')
